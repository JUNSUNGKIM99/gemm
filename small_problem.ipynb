# %%
import subprocess
from matplotlib import pyplot as plt 
import numpy as np
import json

# %%
batch_size = (1, 2, 4, 8, 16, 32, 64, 128, 256)
density = (0.7, 0.65, 0.6, 0.55, 0.5, 0.475, 0.45, 0.425, 0.4, 0.375, 0.35, 0.325, 0.3, 0.275, 0.25, 0.225, 0.2, 0.175, 0.15, 0.125, 0.1, 0.075, 0.05, 0.025, 0.02, 0.01, 0.00175, 0.0015, 0.001)
calculate_sparsity = lambda density: round((1 - density) * 100, 5)
sparsity = list(map(calculate_sparsity, density))
problem = {}
problem["qkv"] = (7680, 2560)
problem['attention_fc'] = (2560, 2560)
problem['linear1'] = (10240, 2560)
problem['linear2'] = (2560,10240)
execution_time = {}
compute_util = {}

# %%
peak_flop = 10496 #  Inst/cycle
peak_flops =  10496 * 2
frequency = 1.39e9    # cycle/nsecond
peak_perf = peak_flop * frequency

# %%
for batch in batch_size:
    execution_time[batch] = {}
    compute_util[batch] = {}
    for sparse in sparsity:
        execution_time[batch][sparse] = 0
        compute_util[batch][sparse] = 0

# %%
for layer in problem:
    m, k = problem[layer]
    print(m,k)
# Out:
# 7680 2560
# 2560 2560
# 10240 2560
# 2560 10240

# %%
with open("./testdata.json", 'w') as json_file:
    json.dump(execution_time, json_file)

# %%
result = subprocess.run(f"ncu --replay-mode kernel --metric smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed,smsp__cycles_elapsed.avg.per_second,gpu__time_duration.sum ./cusparse_sgemm 1024 1 1024 0.3 0", stdout=subprocess.PIPE, shell=True)

# %%
i = result.stdout.decode().find("CsrMMPolicy")
idx_time = result.stdout.decode()[i:].find("gpu__time_duration.sum")
idx_util = result.stdout.decode()[i:].find("smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed")
result.stdout.decode()[i+idx_time:i+idx_time+120].split(), result.stdout.decode()[i+idx_util:i+idx_util+120].split()
# Out:
# (['gpu__time_duration.sum', 'usecond', '8.99'],
#  ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed',
#   'inst/cycle',
#   '25.20'])

# %%
for layer in problem:
    m, k = problem[layer]
    print("Profile: ",layer, m, k)
    for batch in batch_size:
        print("Batch_size:", m, batch, k)
        for sparse in density:
            print("Sparse: ", round(1 - sparse,4))
            result = subprocess.run(f"ncu --replay-mode kernel --metric smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed,smsp__cycles_elapsed.avg.per_second,gpu__time_duration.sum ./cusparse_sgemm {m} {batch} {k} {sparse} 0", stdout=subprocess.PIPE, shell=True)  
            idx = result.stdout.decode().find("CsrMMPolicy")
            idx_time = result.stdout.decode()[idx:].find("gpu__time_duration.sum")
            idx_compute = result.stdout.decode()[idx:].find("smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed")

            time = idx + idx_time 
            compute = idx + idx_compute

            print(result.stdout.decode()[time:time+120].split())
            print(result.stdout.decode()[compute:compute+120].split())

            if result.stdout.decode()[time:time+120].split()[1] == 'msecond':
                execution_time[batch][sparse] = float(result.stdout.decode()[time:time+120].split()[-1]) * 1000.0
            else:
                execution_time[batch][sparse] = float(result.stdout.decode()[time:time+120].split()[-1])
            print((float(result.stdout.decode()[compute:compute+117].split()[-1]) / float(peak_flop)) * 100)
            compute_util[batch][sparse] = (float(result.stdout.decode()[compute:compute+117].split()[-1]) / float(peak_flop)) * 100

with open("./compute_util", 'w') as file:
    json.dump(compute_util, file)

with open("./latency", 'w') as file:
    json.dump(execution_time, file)
# Out:
# Profile:  qkv 7680 2560
# Batch_size: 7680 1 2560
# Sparse:  0.3
# ['gpu__time_duration.sum', 

# Sparse:  0.99
# ['gpu__time_duration.sum', 'usecond', '6.62']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '7.17']
# Sparse:  0.9982
# ['gpu__time_duration.sum', 'usecond', '5.28']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '1.57']
# Sparse:  0.9985
# ['gpu__time_duration.sum', 'usecond', '5.41']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '1.31']
# Sparse:  0.999
# ['gpu__time_duration.sum', 'usecond', '5.86']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '0.81']
# Batch_size: 2560 2 2560
# Sparse:  0.3
# ['gpu__time_duration.sum', 'usecond', '53.18']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '123.89']
# Sparse:  0.35
# ['gpu__time_duration.sum', 'usecond', '50.40']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '121.50']
# Sparse:  0.4
# ['gpu__time_duration.sum', 'usecond', '47.62']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '118.64']
# Sparse:  0.45
# ['gpu__time_duration.sum', 'usecond', '45.25']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '114.50']
# Sparse:  0.5
# ['gpu__time_duration.sum', 'usecond', '41.02']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '114.75']
# Sparse:  0.525
# ['gpu__time_duration.sum', 'usecond', '39.94']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '112.21']
# Sparse:  0.55
# ['gpu__time_duration.sum', 'usecond', '37.82']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '112.18']
# Sparse:  0.575
# ['gpu__time_duration.sum', 'usecond', '37.18']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '107.70']
# Sparse:  0.6
# ['gpu__time_duration.sum', 'usecond', '34.82']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '108.37']
# Sparse:  0.625
# ['gpu__time_duration.sum', 'usecond', '34.05']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '103.79']
# Sparse:  0.65
# ...
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '102.05']
# Sparse:  0.8
# ['gpu__time_duration.sum', 'msecond', '1.29']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '93.23']
# Sparse:  0.825
# ['gpu__time_duration.sum', 'msecond', '1.27']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '82.87']
# Sparse:  0.85
# ['gpu__time_duration.sum', 'msecond', '1.20']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '75.24']
# Sparse:  0.875
# ['gpu__time_duration.sum', 'msecond', '1.13']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '66.62']
# Sparse:  0.9
# ['gpu__time_duration.sum', 'usecond', '986.30']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '60.99']
# Sparse:  0.925
# ['gpu__time_duration.sum', 'usecond', '798.78']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '56.48']
# Sparse:  0.95
# ['gpu__time_duration.sum', 'usecond', '578.53']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '51.97']
# Sparse:  0.975
# ['gpu__time_duration.sum', 'usecond', '312.45']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '48.15']
# Sparse:  0.98
# ['gpu__time_duration.sum', 'usecond', '258.72']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '46.65']
# Sparse:  0.99
# ['gpu__time_duration.sum', 'usecond', '136.42']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '44.09']
# Sparse:  0.9982
# ['gpu__time_duration.sum', 'usecond', '30.08']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '35.25']
# Sparse:  0.9985
# ['gpu__time_duration.sum', 'usecond', '26.21']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '34.68']
# Sparse:  0.999
# ['gpu__time_duration.sum', 'usecond', '20']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '30.29']
# Batch_size: 2560 64 10240
# Sparse:  0.3
# ['gpu__time_duration.sum', 'msecond', '3.77']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '223.28']
# Sparse:  0.35
# ['gpu__time_duration.sum', 'msecond', '3.76']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '208.20']
# Sparse:  0.4
# ['gpu__time_duration.sum', 'msecond', '3.86']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '186.98']
# Sparse:  0.45
# ['gpu__time_duration.sum', 'msecond', '3.85']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '171.76']
# Sparse:  0.5
# ['gpu__time_duration.sum', 'msecond', '3.76']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '159.79']
# Sparse:  0.525
# ['gpu__time_duration.sum', 'msecond', '3.54']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '161.39']
# Sparse:  0.55
# ['gpu__time_duration.sum', 'msecond', '3.72']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '145.85']
# Sparse:  0.575
# ['gpu__time_duration.sum', 'msecond', '3.63']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '141.31']
# Sparse:  0.6
# ['gpu__time_duration.sum', 'msecond', '3.54']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '136.12']
# Sparse:  0.625
# ['gpu__time_duration.sum', 'msecond', '3.49']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '129.23']
# Sparse:  0.65
# ['gpu__time_duration.sum', 'msecond', '3.36']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '125.35']
# Sparse:  0.675
# ['gpu__time_duration.sum', 'msecond', '3.34']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '117.09']
# Sparse:  0.7
# ['gpu__time_duration.sum', 'msecond', '3.27']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '110.48']
# Sparse:  0.725
# ['gpu__time_duration.sum', 'msecond', '3.05']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '108.39']
# Sparse:  0.75
# ['gpu__time_duration.sum', 'msecond', '3.12']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '96.26']
# Sparse:  0.775
# ['gpu__time_duration.sum', 'msecond', '2.94']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '91.95']
# Sparse:  0.8
# ['gpu__time_duration.sum', 'msecond', '2.83']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '84.88']
# Sparse:  0.825
# ['gpu__time_duration.sum', 'msecond', '2.72']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '77.41']
# Sparse:  0.85
# ['gpu__time_duration.sum', 'msecond', '2.56']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '70.63']
# Sparse:  0.875
# ['gpu__time_duration.sum', 'msecond', '2.35']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '63.97']
# Sparse:  0.9
# ['gpu__time_duration.sum', 'msecond', '2.04']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '58.95']
# Sparse:  0.925
# ['gpu__time_duration.sum', 'msecond', '1.64']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '54.98']
# Sparse:  0.95
# ['gpu__time_duration.sum', 'msecond', '1.17']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '51.51']
# Sparse:  0.975
# ['gpu__time_duration.sum', 'usecond', '633.18']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '47.51']
# Sparse:  0.98
# ['gpu__time_duration.sum', 'usecond', '514.18']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '46.83']
# Sparse:  0.99
# ['gpu__time_duration.sum', 'usecond', '269.06']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '44.68']
# Sparse:  0.9982
# ['gpu__time_duration.sum', 'usecond', '56.06']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '37.75']
# Sparse:  0.9985
# ['gpu__time_duration.sum', 'usecond', '48.67']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '37.26']
# Sparse:  0.999
# ['gpu__time_duration.sum', 'usecond', '35.52']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '34.03']
# Batch_size: 2560 128 10240
# Sparse:  0.3
# ['gpu__time_duration.sum', 'msecond', '8.55']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '197.07']
# Sparse:  0.35
# ['gpu__time_duration.sum', 'msecond', '8.36']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '187.02']
# Sparse:  0.4
# ['gpu__time_duration.sum', 'msecond', '8.37']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '172.54']
# Sparse:  0.45
# ['gpu__time_duration.sum', 'msecond', '8.25']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '160.40']
# Sparse:  0.5
# ['gpu__time_duration.sum', 'msecond', '8.11']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '148.33']
# Sparse:  0.525
# ['gpu__time_duration.sum', 'msecond', '7.98']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '143.17']
# Sparse:  0.55
# ['gpu__time_duration.sum', 'msecond', '7.79']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '138.91']
# Sparse:  0.575
# ['gpu__time_duration.sum', 'msecond', '7.73']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '132.30']
# Sparse:  0.6
# ['gpu__time_duration.sum', 'msecond', '7.64']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '125.92']
# Sparse:  0.625
# ['gpu__time_duration.sum', 'msecond', '7.37']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '122.39']
# Sparse:  0.65
# ['gpu__time_duration.sum', 'msecond', '7.37']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '114.29']
# Sparse:  0.675
# ['gpu__time_duration.sum', 'msecond', '7.22']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '108.32']
# Sparse:  0.7
# ['gpu__time_duration.sum', 'msecond', '7.08']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '101.98']
# Sparse:  0.725
# ['gpu__time_duration.sum', 'msecond', '6.89']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '96.09']
# Sparse:  0.75
# ['gpu__time_duration.sum', 'msecond', '6.59']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '91.22']
# Sparse:  0.775
# ['gpu__time_duration.sum', 'msecond', '6.34']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '85.41']
# Sparse:  0.8
# ['gpu__time_duration.sum', 'msecond', '6.03']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '79.84']
# Sparse:  0.825
# ['gpu__time_duration.sum', 'msecond', '5.67']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '74.21']
# Sparse:  0.85
# ['gpu__time_duration.sum', 'msecond', '5.35']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '67.49']
# Sparse:  0.875
# ['gpu__time_duration.sum', 'msecond', '4.79']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '62.85']
# Sparse:  0.9
# ['gpu__time_duration.sum', 'msecond', '4.10']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '58.72']
# Sparse:  0.925
# ['gpu__time_duration.sum', 'msecond', '3.32']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '54.39']
# Sparse:  0.95
# ['gpu__time_duration.sum', 'msecond', '2.34']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '51.40']
# Sparse:  0.975
# ['gpu__time_duration.sum', 'msecond', '1.27']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '47.40']
# Sparse:  0.98
# ['gpu__time_duration.sum', 'msecond', '1.03']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '46.64']
# Sparse:  0.99
# ['gpu__time_duration.sum', 'usecond', '530.72']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '45.28']
# Sparse:  0.9982
# ['gpu__time_duration.sum', 'usecond', '106.69']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '39.60']
# Sparse:  0.9985
# ['gpu__time_duration.sum', 'usecond', '92.58']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '39.13']
# Sparse:  0.999
# ['gpu__time_duration.sum', 'usecond', '66.69']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '36.22']
# Batch_size: 2560 256 10240
# Sparse:  0.3
# ['gpu__time_duration.sum', 'msecond', '18.20']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '185.04']
# Sparse:  0.35
# ['gpu__time_duration.sum', 'msecond', '17.86']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '175.13']
# Sparse:  0.4
# ['gpu__time_duration.sum', 'msecond', '18.04']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '160.06']
# Sparse:  0.45
# ['gpu__time_duration.sum', 'msecond', '17.09']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '154.85']
# Sparse:  0.5
# ['gpu__time_duration.sum', 'msecond', '16.88']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '142.52']
# Sparse:  0.525
# ['gpu__time_duration.sum', 'msecond', '16.73']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '136.65']
# Sparse:  0.55
# ['gpu__time_duration.sum', 'msecond', '16.63']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '130.19']
# Sparse:  0.575
# ['gpu__time_duration.sum', 'msecond', '16.13']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '126.75']
# Sparse:  0.6
# ['gpu__time_duration.sum', 'msecond', '16.09']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '119.61']
# Sparse:  0.625
# ['gpu__time_duration.sum', 'msecond', '15.71']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '114.90']
# Sparse:  0.65
# ['gpu__time_duration.sum', 'msecond', '15.54']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '108.61']
# Sparse:  0.675
# ['gpu__time_duration.sum', 'msecond', '14.99']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '104.32']
# Sparse:  0.7
# ['gpu__time_duration.sum', 'msecond', '14.54']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '99.26']
# Sparse:  0.725
# ['gpu__time_duration.sum', 'msecond', '14.29']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '92.57']
# Sparse:  0.75
# ['gpu__time_duration.sum', 'msecond', '13.61']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '88.39']
# Sparse:  0.775
# ['gpu__time_duration.sum', 'msecond', '13.12']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '82.50']
# Sparse:  0.8
# ['gpu__time_duration.sum', 'msecond', '12.39']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '77.66']
# Sparse:  0.825
# ['gpu__time_duration.sum', 'msecond', '11.67']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '72.13']
# Sparse:  0.85
# ['gpu__time_duration.sum', 'msecond', '10.70']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '67.47']
# Sparse:  0.875
# ['gpu__time_duration.sum', 'msecond', '9.53']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '63.11']
# Sparse:  0.9
# ['gpu__time_duration.sum', 'msecond', '8.21']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '58.58']
# Sparse:  0.925
# ['gpu__time_duration.sum', 'msecond', '6.57']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '54.93']
# Sparse:  0.95
# ['gpu__time_duration.sum', 'msecond', '4.88']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '49.29']
# Sparse:  0.975
# ['gpu__time_duration.sum', 'msecond', '3.31']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '36.34']
# Sparse:  0.98
# ['gpu__time_duration.sum', 'msecond', '2.75']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '35.05']
# Sparse:  0.99
# ['gpu__time_duration.sum', 'msecond', '1.53']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '31.36']
# Sparse:  0.9982
# ['gpu__time_duration.sum', 'usecond', '211.39']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '39.94']
# Sparse:  0.9985
# ['gpu__time_duration.sum', 'usecond', '182.62']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '39.62']
# Sparse:  0.999
# ['gpu__time_duration.sum', 'usecond', '130.72']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '36.90']

# %%
compute_util[1]
# Out:
# {30.0: 0,
#  35.0: 0,
#  40.0: 0,
#  45.0: 0,
#  50.0: 0,
#  52.5: 0,
#  55.0: 0,
#  57.5: 0,
#  60.0: 0,
#  62.5: 0,
#  65.0: 0,
#  67.5: 0,
#  70.0: 0,
#  72.5: 0,
#  75.0: 0,
#  77.5: 0,
#  80.0: 0,
#  82.5: 0,
#  85.0: 0,
#  87.5: 0,
#  90.0: 0,
#  92.5: 0,
#  95.0: 0,
#  97.5: 0,
#  98.0: 0,
#  99.0: 0,
#  99.825: 0,
#  99.85: 0,
#  99.9: 0,
#  0.7: 0.6737804878048781,
#  0.65: 0.661204268292683,
#  0.6: 0.6564405487804879,
#  0.55: 0.6700647865853658,
#  0.5: 0.6644435975609756,
#  0.475: 0.6500571646341464,
#  0.45: 0.6529153963414633,
#  0.425: 0.6453887195121951,
#  0.4: 0.6545350609756098,
#  0.375: 0.6492949695121952,
#  0.35: 0.6479611280487806,
#  0.325: 0.6419588414634146,
#  0.3: 0.6405297256097562,
#  0.275: 0.6306211890243902,
#  0.25: 0.6231897865853658,
#  0.225: 0.6223323170731707,
#  0.2: 0.5938452743902439,
#  0.175: 0.5901295731707317,
#  0.15: 0.5804115853658537,
#  0.125: 0.551829268292683,
#  0.1: 0.5249618902439025,
#  0.075: 0.4771341463414634,
#  0.05: 0.41873094512195125,
#  0.025: 0.29868521341463417,
#  0.02: 0.26171875,
#  0.01: 0.17444740853658536,
#  0.00175: 0.0545922256097561,
#  0.0015: 0.04563643292682927,
#  0.001: 0.03515625}

# %%
with open("./compute_util1.json", 'w') as file:
    json.dump(compute_util, file)

with open("./latency1.json", 'w') as file:
    json.dump(execution_time, file)

# %%
baseline = {}
baseline['compute'] = {}
baseline['time'] = {}
for layer in problem:
    baseline['compute'][layer] = {}
    baseline['time'][layer] = {}

# %%
baseline
# Out:
# {'compute': {'qkv': {}, 'attention_fc': {}, 'linear1': {}, 'linear2': {}},
#  'time': {'qkv': {}, 'attention_fc': {}, 'linear1': {}, 'linear2': {}}}

# %%
a, b = result.stdout.decode().find("smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed"),result.stdout.decode().find("gpu__time_duration.sum")

# %%
result.stdout.decode()[a:a+120].split(), result.stdout.decode()[b:b+120].split()
# Out:
# (['sm__throughput.avg.pct_of_peak_sustained_elapsed',
#   '%',
#   '22.127333',
#   '22.472679',
#   '22.319877'],
#  ['gpu__time_duration.sum', 'usecond', '34.240000', '35.552000', '34.867810'])

# %%
#cuBlas, Baseline
for layer in problem:
    m, k = problem[layer]
    print("Profile: ",layer, m, k)
    for batch in batch_size:
        print("Batch_size:", m, batch, k)
        result = subprocess.run(f"ncu --replay-mode kernel --metric smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed,smsp__cycles_elapsed.avg.per_second,gpu__time_duration.sum ./cublas_sgemm {m} {batch} {k} 0", stdout=subprocess.PIPE, shell=True)  
        idx1 = result.stdout.decode().find("gpu__time_duration.sum")
        baseline['time'][layer][batch] = float(result.stdout.decode()[idx1:idx1+120].split()[-1])
        
        idx2 = result.stdout.decode().find("smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed")
        baseline['compute'][layer][batch] = (float(result.stdout.decode()[idx2:idx2+117].split()[-1]) / float(peak_flop)) * 100.0
        print(result.stdout.decode()[idx1:idx1+120].split())
        print(result.stdout.decode()[idx2:idx2+120].split())
# Out:
# Profile:  qkv 7680 2560
# Batch_size: 7680 1 2560
# ['gpu__time_duration.sum', 'usecond', '96.672000', '98.336000', '97.383619']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '23.406406', '23.772617', '23.610685']
# Batch_size: 7680 2 2560
# ['gpu__time_duration.sum', 'usecond', '99.648000', '100.416000', '100.068571']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '17.934592', '18.029137', '17.974133']
# Batch_size: 7680 4 2560
# ['gpu__time_duration.sum', 'usecond', '98.656000', '99.680000', '99.108571']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '24.671530', '25.017670', '24.875442']
# Batch_size: 7680 8 2560
# ['gpu__time_duration.sum', 'usecond', '115.584000', '116.896000', '116.091429']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '46.108100', '46.389750', '46.276350']
# Batch_size: 7680 16 2560
# ['gpu__time_duration.sum', 'usecond', '116.192000', '117.408000', '116.592762']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '45.745377', '46.047060', '45.882804']
# Batch_size: 7680 32 2560
# ['gpu__time_duration.sum', 'usecond', '125.568000', '127.840000', '126.832762']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '57.349286', '57.848009', '57.609072']
# Batch_size: 7680 64 2560
# ['gpu__time_duration.sum', 'usecond', '164.640000', '165.248000', '164.941714']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '62.568395', '62.790716', '62.727178']
# Batch_size: 7680 128 2560
# ['gpu__time_duration.sum', 'usecond', '312.192000', '312.864000', '312.466286']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '65.746387', '65.843122', '65.809086']
# Batch_size: 7680 256 2560
# ['gpu__time_duration.sum', 'usecond', '546.528000', '548.256000', '547.608381']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '72.215344', '72.464650', '72.392292']
# Profile:  attention_fc 2560 2560
# Batch_size: 2560 1 2560
# ['gpu__time_duration.sum', 'usecond', '34.304000', '35.616000', '34.930286']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '22.118562', '22.472535', '22.310118']
# Batch_size: 2560 2 2560
# ['gpu__time_duration.sum', 'usecond', '40.864000', '41.920000', '41.426286']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '63.763935', '65.825325', '64.984510']
# Batch_size: 2560 4 2560
# ['gpu__time_duration.sum', 'usecond', '40.896000', '41.984000', '41.369905']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '63.951239', '65.979104', '64.985947']
# Batch_size: 2560 8 2560
# ['gpu__time_duration.sum', 'usecond', '40.992000', '42.624000', '41.475048']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '63.713750', '65.424177', '64.788696']
# Batch_size: 2560 16 2560
# ['gpu__time_duration.sum', 'usecond', '41.184000', '42.432000', '41.641143']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '63.566703', '65.470686', '64.544727']
# Batch_size: 2560 32 2560
# ['gpu__time_duration.sum', 'usecond', '59.648000', '60.256000', '59.943619']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '36.345603', '36.511974', '36.422175']
# Batch_size: 2560 64 2560
# ['gpu__time_duration.sum', 'usecond', '65.408000', '66.304000', '65.854476']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '75.259061', '76.143292', '75.624363']
# Batch_size: 2560 128 2560
# ['gpu__time_duration.sum', 'usecond', '113.696000', '115.008000', '114.140952']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '63.792898', '64.311989', '64.089839']
# Batch_size: 2560 256 2560
# ['gpu__time_duration.sum', 'usecond', '200.320000', '201.888000', '201.237333']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '71.617486', '72.180356', '71.931336']
# Profile:  linear1 10240 2560
# Batch_size: 10240 1 2560
# ['gpu__time_duration.sum', 'usecond', '127.520000', '128.608000', '127.856762']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '64.025897', '64.545135', '64.250937']
# Batch_size: 10240 2 2560
# ['gpu__time_duration.sum', 'usecond', '130.880000', '132.896000', '131.683048']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '74.326473', '75.931049', '75.256463']
# Batch_size: 10240 4 2560
# ['gpu__time_duration.sum', 'usecond', '130.944000', '132.800000', '131.707429']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '74.815571', '75.989271', '75.265416']
# Batch_size: 10240 8 2560
# ['gpu__time_duration.sum', 'usecond', '130.912000', '133.312000', '131.724190']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '74.566542', '75.866350', '75.273885']
# Batch_size: 10240 16 2560
# ['gpu__time_duration.sum', 'usecond', '130.976000', '133.120000', '131.919238']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '73.781823', '75.889863', '75.330797']
# Batch_size: 10240 32 2560
# ['gpu__time_duration.sum', 'usecond', '136.128000', '138.752000', '137.619810']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '69.995944', '72.093342', '71.269440']
# Batch_size: 10240 64 2560
# ['gpu__time_duration.sum', 'usecond', '205.024000', '207.232000', '206.134857']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '66.264058', '66.513706', '66.380233']
# Batch_size: 10240 128 2560
# ['gpu__time_duration.sum', 'usecond', '367.328000', '369.792000', '368.323048']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '72.054161', '72.350658', '72.206724']
# Batch_size: 10240 256 2560
# ['gpu__time_duration.sum', 'usecond', '734.464000', '738.816000', '735.756190']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '71.576555', '71.746708', '71.66072']
# Profile:  linear2 2560 10240
# Batch_size: 2560 1 10240
# ['gpu__time_duration.sum', 'usecond', '136.832000', '139.264000', '138.328381']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '65.833467', '66.813458', '66.172972']
# Batch_size: 2560 2 10240
# ['gpu__time_duration.sum', 'usecond', '137.184000', '139.072000', '138.247619']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '65.642777', '66.608536', '66.153176']
# Batch_size: 2560 4 10240
# ['gpu__time_duration.sum', 'usecond', '131.232000', '133.504000', '131.983238']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '74.655750', '75.813540', '75.254055']
# Batch_size: 2560 8 10240
# ['gpu__time_duration.sum', 'usecond', '131.328000', '132.864000', '132.120381']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '74.642118', '75.362766', '75.017699']
# Batch_size: 2560 16 10240
# ['gpu__time_duration.sum', 'usecond', '138.656000', '141.216000', '140.341333']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '64.312657', '65.873171', '65.202545']
# Batch_size: 2560 32 10240
# ['gpu__time_duration.sum', 'usecond', '134.208000', '140.640000', '136.356571']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '51.596924', '53.679969', '52.948101']
# Batch_size: 2560 64 10240
# ['gpu__time_duration.sum', 'usecond', '245.888000', '248.256000', '247.247238']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '57.687395', '58.054304', '57.943270']
# Batch_size: 2560 128 10240
# ['gpu__time_duration.sum', 'usecond', '384.576000', '388.512000', '386.706286']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '72.816219', '73.257950', '73.061240']
# Batch_size: 2560 256 10240
# ['gpu__time_duration.sum', 'usecond', '750.112000', '757.952000', '754.369524']
# ['sm__throughput.avg.pct_of_peak_sustained_elapsed', '%', '74.784136', '75.280550', '75.07212']

# %%
with open("./baseline.json", 'w') as file:
    json.dump(baseline, file)

# %%
for key in baseline['time']:
    values = baseline['time'][key]
    print(values)
# Out:
# {1: 97.383619, 2: 100.068571, 4: 99.108571, 8: 116.091429, 16: 116.592762, 32: 126.832762, 64: 164.941714, 128: 312.466286, 256: 547.608381}
# {1: 34.930286, 2: 41.426286, 4: 41.369905, 8: 41.475048, 16: 41.641143, 32: 59.943619, 64: 65.854476, 128: 114.140952, 256: 201.237333}
# {1: 127.856762, 2: 131.683048, 4: 131.707429, 8: 131.72419, 16: 131.919238, 32: 137.61981, 64: 206.134857, 128: 368.323048, 256: 735.75619}
# {1: 138.328381, 2: 138.247619, 4: 131.983238, 8: 132.120381, 16: 140.341333, 32: 136.356571, 64: 247.247238, 128: 386.706286, 256: 754.369524}

# %%
#compute_util, execution_time, baseline

# %%
for batch_size in compute_util:
    for dense in compute_util[batch_size]:
        print(compute_util[batch_size][dense])
print(len(compute_util))
# Out:
# 17.48279
# 17.466215
# 17.477086
# 17.48241
# 17.449177
# 17.489151
# 17.413046
# 17.546226
# 17.494218
# 17.475552
# 17.560623
# 17.561836
# 17.544823
# 17.552697
# 17.559802
# 17.558135
# 17.455843
# 17.542881
# 17.47784
# 17.483838
# 17.472221
# 17.472899
# 17.447281
# 17.6142
# 17.399356
# 17.460912
# 17.527381
# 17.536464
# 17.478566
# 23.644179
