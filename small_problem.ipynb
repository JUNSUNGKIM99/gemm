# %%
import subprocess
from matplotlib import pyplot as plt 
import numpy as np
import json

# %%
batch_size = (1, 2, 4, 8, 16, 32, 64, 128, 256)
density = (0.7, 0.65, 0.6, 0.55, 0.5, 0.475, 0.45, 0.425, 0.4, 0.375, 0.35, 0.325, 0.3, 0.275, 0.25, 0.225, 0.2, 0.175, 0.15, 0.125, 0.1, 0.075, 0.05, 0.025, 0.02, 0.01, 0.00175, 0.0015, 0.001)
calculate_sparsity = lambda density: round((1 - density) * 100, 5)
sparsity = list(map(calculate_sparsity, density))
problem = {}
problem["qkv"] = (7680, 2560)
problem['attention_fc'] = (2560, 2560)
problem['linear1'] = (10240, 2560)
problem['linear2'] = (2560,10240)
execution_time = {}
compute_util = {}

# %%
peak_flop = 10496 #  Inst/cycle
peak_flops =  10496 * 2
frequency = 1.39e9    # cycle/nsecond
peak_perf = peak_flop * frequency

# %%
for layer in problem:
    execution_time[layer] = {}
    compute_util[layer] = {}
    for batch in batch_size:
        execution_time[layer][batch] = {}
        compute_util[layer][batch] = {}
        for sparse in density:
            execution_time[layer][batch][sparse] = 0
            compute_util[layer][batch][sparse] = 0

# %%
for layer in problem:
    m, k = problem[layer]
    print(m,k)
# Out:
# 7680 2560
# 2560 2560
# 10240 2560
# 2560 10240

# %%
with open("./testdata.json", 'w') as json_file:
    json.dump(execution_time, json_file)

# %%
result = subprocess.run(f"ncu --replay-mode kernel --metric smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed,smsp__cycles_elapsed.avg.per_second,gpu__time_duration.sum ./cusparse_sgemm 1024 1 1024 0.3 0", stdout=subprocess.PIPE, shell=True)

# %%
i = result.stdout.decode().find("CsrMMPolicy")
idx_time = result.stdout.decode()[i:].find("gpu__time_duration.sum")
idx_util = result.stdout.decode()[i:].find("smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed")
result.stdout.decode()[i+idx_time:i+idx_time+120].split(), result.stdout.decode()[i+idx_util:i+idx_util+120].split()
# Out:
# (['gpu__time_duration.sum', 'usecond', '8.99'],
#  ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed',
#   'inst/cycle',
#   '25.20'])

# %%
for layer in problem:
    m, k = problem[layer]
    print("Profile: ",layer, m, k)
    for batch in batch_size:
        print("Batch_size:", m, batch, k)
        for sparse in density:
            print("Sparse: ", round(1 - sparse,4))
            result = subprocess.run(f"ncu --replay-mode kernel --metric smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed,smsp__cycles_elapsed.avg.per_second,gpu__time_duration.sum ./cusparse_sgemm {m} {batch} {k} {sparse} 0", stdout=subprocess.PIPE, shell=True)  
            idx = result.stdout.decode().find("CsrMMPolicy")
            idx_time = result.stdout.decode()[idx:].find("gpu__time_duration.sum")
            idx_compute = result.stdout.decode()[idx:].find("smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed")

            time = idx + idx_time 
            compute = idx + idx_compute

            print(result.stdout.decode()[time:time+120].split())
            print(result.stdout.decode()[compute:compute+120].split())

            if result.stdout.decode()[time:time+120].split()[1] == 'msecond':
                execution_time[layer][batch][sparse] = float(result.stdout.decode()[time:time+120].split()[-1]) * 1000.0
            else:
                execution_time[layer][batch][sparse] = float(result.stdout.decode()[time:time+120].split()[-1])
            print((float(result.stdout.decode()[compute:compute+117].split()[-1]) / float(peak_flop)) * 100)
            compute_util[layer][batch][sparse] = (float(result.stdout.decode()[compute:compute+117].split()[-1]) / float(peak_flop)) * 100

with open("./latency2.json", 'w') as file:
    json.dump(execution_time, file)
    
with open("./compute_util2.json", 'w') as file:
    json.dump(compute_util, file)
# Out:
# Profile:  qkv 7680 2560
# Batch_size: 7680 1 2560
# Sparse:  0.3
# ['gpu__time_duration.sum', 'usecond', '139.23']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '70.91']
# 0.6755907012195121
# Sparse:  0.35
# ['gpu__time_duration.sum', 'usecond', '129.98']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '70.70']
# 0.6735899390243902
# Sparse:  0.4
# ['gpu__time_duration.sum', 'usecond', '120.90']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '70.03']
# 0.6672065548780488
# Sparse:  0.45
# ['gpu__time_duration.sum', 'usecond', '114.37']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '68.03']
# 0.6481516768292682
# Sparse:  0.5
# ['gpu__time_duration.sum', 'usecond', '103.26']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '68.50']
# 0.6526295731707317
# Sparse:  0.525
# ['gpu__time_duration.sum', 'usecond', '97.70']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '68.82']
# 0.6556783536585366
# Sparse:  0.55
# ['gpu__time_duration.sum', 'usecond', '94.78']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '67.17']
# 0.6399580792682927
# Sparse:  0.575
# ['gpu__time_duration.sum', 'usecond', '89.82']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '66.78']
# 0.6362423780487805
# Sparse:  0.6
# ['gpu__time_duration.sum', 'usecond', '85.31']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '66.18']
# 0.6305259146341464
# Sparse:  0.625
# ['gpu__time_duration.sum', 'usecond', '80.38']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '65.87']
# 0.6275724085365854
# Sparse:  0.65
# ['gpu__time_duration.sum', 'usecond', '76.19']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '64.87']
# 0.6180449695121951
# Sparse:  0.675
# ['gpu__time_duration.sum', 'usecond', '71.49']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '64.35']
# 0.6130907012195121
# Sparse:  0.7
# ['gpu__time_duration.sum', 'usecond', '66.85']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '63.35']
# 0.603563262195122
# Sparse:  0.725
# ['gpu__time_duration.sum', 'usecond', '62.34']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '62.29']
# 0.5934641768292683
# Sparse:  0.75
# ['gpu__time_duration.sum', 'usecond', '57.89']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '60.99']
# 0.581078506097561
# Sparse:  0.775
# ['gpu__time_duration.sum', 'usecond', '52.42']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '60.63']
# 0.5776486280487805
# Sparse:  0.8
# ['gpu__time_duration.sum', 'usecond', '48.86']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '57.83']
# 0.5509717987804877
# Sparse:  0.825
# ['gpu__time_duration.sum', 'usecond', '43.71']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '56.76']
# 0.5407774390243902
# Sparse:  0.85
# ['gpu__time_duration.sum', 'usecond', '39.81']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '53.22']
# 0.5070503048780488
# Sparse:  0.875
# ['gpu__time_duration.sum', 'usecond', '34.66']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '51.23']
# 0.4880907012195122
# Sparse:  0.9
# ['gpu__time_duration.sum', 'usecond', '30.88']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '45.99']
# 0.4381669207317074
# Sparse:  0.925
# ['gpu__time_duration.sum', 'usecond', '25.47']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '41.60']
# 0.39634146341463417
# Sparse:  0.95
# ['gpu__time_duration.sum', 'usecond', '21.47']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '33.10']
# 0.3153582317073171
# Sparse:  0.975
# ['gpu__time_duration.sum', 'usecond', '12.83']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '27.82']
# 0.2650533536585366
# Sparse:  0.98
# ['gpu__time_duration.sum', 'usecond', '12']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '23.75']
# 0.22627667682926828
# Sparse:  0.99
# ['gpu__time_duration.sum', 'usecond', '8.90']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '16.06']
# 0.1530106707317073
# Sparse:  0.9982
# ['gpu__time_duration.sum', 'usecond', '5.41']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '4.64']
# 0.04420731707317073
# Sparse:  0.9985
# ['gpu__time_duration.sum', 'usecond', '5.41']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '3.94']
# 0.03753810975609756
# Sparse:  0.999
# ['gpu__time_duration.sum', 'usecond', '5.63']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '2.53']
# 0.024104420731707314
# Batch_size: 7680 2 2560
# Sparse:  0.3
# ['gpu__time_duration.sum', 'usecond', '142.66']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '138.95']
# 1.3238376524390243
# Sparse:  0.35
# ['gpu__time_duration.sum', 'usecond', '132.90']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '138.53']
# 1.3198361280487805
# Sparse:  0.4
# ['gpu__time_duration.sum', 'usecond', '123.78']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '137.33']
# 1.3084032012195121
# Sparse:  0.45
# ['gpu__time_duration.sum', 'usecond', '116.51']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '133.68']
# 1.2736280487804879
# Sparse:  0.5
# ['gpu__time_duration.sum', 'usecond', '106.27']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '132.87']
# 1.2659108231707317
# Sparse:  0.525
# ['gpu__time_duration.sum', 'usecond', '101.92']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '131.56']
# 1.2534298780487805
# Sparse:  0.55
# ['gpu__time_duration.sum', 'usecond', '96.03']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '132.30']
# 1.2604801829268293
# Sparse:  0.575
# ['gpu__time_duration.sum', 'usecond', '93.02']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '129.03']
# 1.229325457317073
# Sparse:  0.6
# ['gpu__time_duration.sum', 'usecond', '87.42']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '129.20']
# 1.2309451219512193
# Sparse:  0.625
# ['gpu__time_duration.sum', 'usecond', '83.04']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '127.56']
# 1.2153201219512195
# Sparse:  0.65
# ['gpu__time_duration.sum', 'usecond', '78.78']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '125.47']
# 1.1954077743902438
# Sparse:  0.675
# ['gpu__time_duration.sum', 'usecond', '74.11']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '123.93']
# 1.180735518292683
# Sparse:  0.7
# ['gpu__time_duration.sum', 'usecond', '68.70']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '123.34']
# 1.1751143292682926
# Sparse:  0.725
# ['gpu__time_duration.sum', 'usecond', '65.02']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '119.49']
# 1.13843368902439
# Sparse:  0.75
# ['gpu__time_duration.sum', 'usecond', '58.50']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '120.70']
# 1.1499618902439024
# Sparse:  0.775
# ['gpu__time_duration.sum', 'usecond', '55.30']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '114.97']
# 1.0953696646341464
# Sparse:  0.8
# ['gpu__time_duration.sum', 'usecond', '49.47']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '114.25']
# 1.0885099085365855
# Sparse:  0.825
# ['gpu__time_duration.sum', 'usecond', '45.86']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '108.34']
# 1.032202743902439
# Sparse:  0.85
# ['gpu__time_duration.sum', 'usecond', '40.42']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '105.08']
# 1.001143292682927
# Sparse:  0.875
# ['gpu__time_duration.sum', 'usecond', '36.48']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '96.99']
# 0.9240663109756097
# Sparse:  0.9
# ['gpu__time_duration.sum', 'usecond', '31.33']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '90.32']
# 0.8605182926829267
# Sparse:  0.925
# ['gpu__time_duration.sum', 'usecond', '27.68']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '76.73']
# 0.7310403963414634
# Sparse:  0.95
# ['gpu__time_duration.sum', 'usecond', '23.23']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '60.94']
# 0.5806021341463414
# Sparse:  0.975
# ['gpu__time_duration.sum', 'usecond', '13.28']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '53.59']
# 0.5105754573170732
# Sparse:  0.98
# ['gpu__time_duration.sum', 'usecond', '12.90']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '43.99']
# 0.41911204268292684
# Sparse:  0.99
# ['gpu__time_duration.sum', 'usecond', '10.27']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '27.66']
# 0.26352896341463417
# Sparse:  0.9982
# ['gpu__time_duration.sum', 'usecond', '6.08']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '8.20']
# 0.078125
# Sparse:  0.9985
# ['gpu__time_duration.sum', 'usecond', '5.98']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '7.15']
# 0.06812118902439025
# Sparse:  0.999
# ['gpu__time_duration.sum', 'usecond', '5.79']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '4.92']
# 0.046875
# Batch_size: 7680 4 2560
# Sparse:  0.3
# ['gpu__time_duration.sum', 'usecond', '149.12']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '266.39']
# 2.538014481707317
# Sparse:  0.35
# ['gpu__time_duration.sum', 'usecond', '138.24']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '265.67']
# 2.531154725609756
# Sparse:  0.4
# ['gpu__time_duration.sum', 'usecond', '129.28']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '262.25']
# 2.4985708841463414
# Sparse:  0.45
# ['gpu__time_duration.sum', 'usecond', '119.39']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '260.44']
# 2.4813262195121952
# Sparse:  0.5
# ['gpu__time_duration.sum', 'usecond', '110.40']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '255.96']
# 2.438643292682927
# Sparse:  0.525
# ['gpu__time_duration.sum', 'usecond', '105.44']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '255.77']
# 2.436833079268293
# Sparse:  0.55
# ['gpu__time_duration.sum', 'usecond', '101.18']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '251.45']
# 2.3956745426829267
# Sparse:  0.575
# ['gpu__time_duration.sum', 'usecond', '97.38']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '247.76']
# 2.3605182926829267
# Sparse:  0.6
# ['gpu__time_duration.sum', 'usecond', '91.97']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '245.92']
# 2.3429878048780486
# Sparse:  0.625
# ['gpu__time_duration.sum', 'usecond', '87.71']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '241.76']
# 2.3033536585365852
# Sparse:  0.65
# ['gpu__time_duration.sum', 'usecond', '82.88']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '239.90']
# 2.2856326219512195
# Sparse:  0.675
# ['gpu__time_duration.sum', 'usecond', '77.98']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '235.97']
# 2.2481897865853657
# Sparse:  0.7
# ['gpu__time_duration.sum', 'usecond', '72.90']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '233.75']
# 2.2270388719512195
# Sparse:  0.725
# ['gpu__time_duration.sum', 'usecond', '67.65']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '229.93']
# 2.190644054878049
# Sparse:  0.75
# ['gpu__time_duration.sum', 'usecond', '62.02']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '229.16']
# 2.183307926829268
# Sparse:  0.775
# ['gpu__time_duration.sum', 'usecond', '56.54']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '226.19']
# 2.155011432926829
# Sparse:  0.8
# ['gpu__time_duration.sum', 'usecond', '51.55']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '220.69']
# 2.102610518292683
# Sparse:  0.825
# ['gpu__time_duration.sum', 'usecond', '46.27']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '215.21']
# 2.0504001524390243
# Sparse:  0.85
# ['gpu__time_duration.sum', 'usecond', '42.05']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '202.98']
# 1.9338795731707314
# Sparse:  0.875
# ['gpu__time_duration.sum', 'usecond', '38.56']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '183.67']
# 1.749904725609756
# Sparse:  0.9
# ['gpu__time_duration.sum', 'usecond', '33.50']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '169.93']
# 1.618997713414634
# Sparse:  0.925
# ['gpu__time_duration.sum', 'usecond', '29.41']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '145.19']
# 1.3832888719512195
# Sparse:  0.95
# ['gpu__time_duration.sum', 'usecond', '25.89']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '109.93']
# 1.0473513719512197
# Sparse:  0.975
# ['gpu__time_duration.sum', 'usecond', '15.94']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '89.39']
# 0.8516577743902439
# Sparse:  0.98
# ['gpu__time_duration.sum', 'usecond', '14.53']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '78.83']
# 0.7510480182926829
# Sparse:  0.99
# ['gpu__time_duration.sum', 'usecond', '11.52']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '49.57']
# 0.4722751524390244
# Sparse:  0.9982
# ['gpu__time_duration.sum', 'usecond', '7.17']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '13.97']
# 0.13309832317073172
# Sparse:  0.9985
# ['gpu__time_duration.sum', 'usecond', '6.40']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '13.53']
# 0.12890624999999997
# Sparse:  0.999
# ['gpu__time_duration.sum', 'usecond', '6.56']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '8.77']
# 0.08355564024390244
# Batch_size: 7680 8 2560
# Sparse:  0.3
# ['gpu__time_duration.sum', 'usecond', '282.02']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '281.62']
# 2.6831173780487805
# Sparse:  0.35
# ['gpu__time_duration.sum', 'usecond', '262.50']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '280.96']
# 2.676829268292683
# Sparse:  0.4
# ['gpu__time_duration.sum', 'usecond', '244.54']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '278.41']
# 2.652534298780488
# Sparse:  0.45
# ['gpu__time_duration.sum', 'usecond', '233.50']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '267.31']
# 2.546779725609756
# Sparse:  0.5
# ['gpu__time_duration.sum', 'usecond', '206.91']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '274.26']
# 2.6129954268292686
# Sparse:  0.525
# ['gpu__time_duration.sum', 'usecond', '195.01']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '276.46']
# 2.6339557926829267
# Sparse:  0.55
# ['gpu__time_duration.sum', 'usecond', '186.24']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '274.20']
# 2.6124237804878048
# Sparse:  0.575
# ['gpu__time_duration.sum', 'usecond', '178.53']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '270.19']
# 2.57421875
# Sparse:  0.6
# ['gpu__time_duration.sum', 'usecond', '167.39']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '270.10']
# 2.573361280487805
# Sparse:  0.625
# ['gpu__time_duration.sum', 'usecond', '156.03']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '271.64']
# 2.5880335365853657
# Sparse:  0.65
# ['gpu__time_duration.sum', 'usecond', '145.22']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '272.56']
# 2.5967987804878048
# Sparse:  0.675
# ['gpu__time_duration.sum', 'usecond', '133.70']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '274.95']
# 2.6195693597560976
# Sparse:  0.7
# ['gpu__time_duration.sum', 'usecond', '119.97']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '283.06']
# 2.6968368902439024
# Sparse:  0.725
# ['gpu__time_duration.sum', 'usecond', '108.10']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '290.10']
# 2.76391006097561
# Sparse:  0.75
# ['gpu__time_duration.sum', 'usecond', '98.94']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '288.58']
# 2.749428353658536
# Sparse:  0.775
# ['gpu__time_duration.sum', 'usecond', '91.01']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '282.47']
# 2.6912157012195124
# Sparse:  0.8
# ['gpu__time_duration.sum', 'usecond', '81.44']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '280.99']
# 2.6771150914634148
# Sparse:  0.825
# ['gpu__time_duration.sum', 'usecond', '74.62']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '267.83']
# 2.551733993902439
# Sparse:  0.85
# ['gpu__time_duration.sum', 'usecond', '66.88']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '256.21']
# 2.441025152439024
# Sparse:  0.875
# ['gpu__time_duration.sum', 'usecond', '60.38']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '236.06']
# 2.249047256097561
# Sparse:  0.9
# ['gpu__time_duration.sum', 'usecond', '51.55']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '219.90']
# 2.0950838414634148
# Sparse:  0.925
# ['gpu__time_duration.sum', 'usecond', '45.02']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '188.89']
# 1.7996379573170729
# Sparse:  0.95
# ['gpu__time_duration.sum', 'usecond', '37.28']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '152.54']
# 1.4533155487804876
# Sparse:  0.975
# ['gpu__time_duration.sum', 'usecond', '23.36']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '122.40']
# 1.166158536585366
# Sparse:  0.98
# ['gpu__time_duration.sum', 'usecond', '21.63']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '105.90']
# 1.008955792682927
# Sparse:  0.99
# ['gpu__time_duration.sum', 'usecond', '16.90']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '67.67']
# 0.6447217987804879
# Sparse:  0.9982
# ['gpu__time_duration.sum', 'usecond', '9.22']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '21.82']
# 0.20788871951219512
# Sparse:  0.9985
# ['gpu__time_duration.sum', 'usecond', '8.64']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '20.06']
# 0.19112042682926828
# Sparse:  0.999
# ['gpu__time_duration.sum', 'usecond', '7.68']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '14.94']
# 0.14233993902439024
# Batch_size: 7680 16 2560
# Sparse:  0.3
# ['gpu__time_duration.sum', 'usecond', '548.16']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '289.72']
# 2.760289634146342
# Sparse:  0.35
# ['gpu__time_duration.sum', 'usecond', '505.38']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '290.63']
# 2.7689596036585367
# Sparse:  0.4
# ['gpu__time_duration.sum', 'usecond', '468.42']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '290.65']
# 2.7691501524390243
# Sparse:  0.45
# ['gpu__time_duration.sum', 'usecond', '448.74']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '278.08']
# 2.649390243902439
# Sparse:  0.5
# ['gpu__time_duration.sum', 'usecond', '398.53']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '284.75']
# 2.712938262195122
# Sparse:  0.525
# ['gpu__time_duration.sum', 'usecond', '376.42']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '286.44']
# 2.7290396341463414
# Sparse:  0.55
# ['gpu__time_duration.sum', 'usecond', '354.88']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '286.59']
# 2.7304687499999996
# Sparse:  0.575
# ['gpu__time_duration.sum', 'usecond', '338.98']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '283.49']
# 2.7009336890243905
# Sparse:  0.6
# ['gpu__time_duration.sum', 'usecond', '318.34']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '285.25']
# 2.717701981707317
# Sparse:  0.625
# ['gpu__time_duration.sum', 'usecond', '291.81']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '290.49']
# 2.767625762195122
# Sparse:  0.65
# ['gpu__time_duration.sum', 'usecond', '268.48']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '295.95']
# 2.8196455792682924
# Sparse:  0.675
# ['gpu__time_duration.sum', 'usecond', '245.89']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '300.01']
# 2.858326981707317
# Sparse:  0.7
# ['gpu__time_duration.sum', 'usecond', '209.76']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '324.76']
# 3.0941310975609757
# Sparse:  0.725
# ['gpu__time_duration.sum', 'usecond', '187.42']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '333.47']
# 3.177115091463415
# Sparse:  0.75
# ['gpu__time_duration.sum', 'usecond', '168.16']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '336.69']
# 3.207793445121951
# Sparse:  0.775
# ['gpu__time_duration.sum', 'usecond', '155.10']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '329.91']
# 3.1431974085365857
# Sparse:  0.8
# ['gpu__time_duration.sum', 'usecond', '143.90']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '316.14']
# 3.0120045731707314
# Sparse:  0.825
# ['gpu__time_duration.sum', 'usecond', '130.91']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '304.16']
# 2.8978658536585367
# Sparse:  0.85
# ['gpu__time_duration.sum', 'usecond', '123.84']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '274.52']
# 2.6154725609756095
# Sparse:  0.875
# ['gpu__time_duration.sum', 'usecond', '107.39']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '265.40']
# 2.5285823170731705
# Sparse:  0.9
# ['gpu__time_duration.sum', 'usecond', '111.36']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '203.55']
# 1.9393102134146343
# Sparse:  0.925
# ['gpu__time_duration.sum', 'usecond', '87.46']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '195.65']
# 1.8640434451219514
# Sparse:  0.95
# ['gpu__time_duration.sum', 'usecond', '96']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '118.33']
# 1.1273818597560976
# Sparse:  0.975
# ['gpu__time_duration.sum', 'usecond', '40.48']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '140.10']
# 1.334794207317073
# Sparse:  0.98
# ['gpu__time_duration.sum', 'usecond', '35.97']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '126.24']
# 1.2027439024390245
# Sparse:  0.99
# ['gpu__time_duration.sum', 'usecond', '28.13']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '80.60']
# 0.7679115853658537
# Sparse:  0.9982
# ['gpu__time_duration.sum', 'usecond', '12.99']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '30.68']
# 0.2923018292682927
# Sparse:  0.9985
# ['gpu__time_duration.sum', 'usecond', '12.13']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '28.24']
# 0.2690548780487805
# Sparse:  0.999
# ['gpu__time_duration.sum', 'usecond', '10.14']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '22.76']
# 0.21684451219512196
# Batch_size: 7680 32 2560
# Sparse:  0.3
# ['gpu__time_duration.sum', 'usecond', '639.46']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '495.89']
# 4.724561737804878
# Sparse:  0.35
# ['gpu__time_duration.sum', 'usecond', '609.82']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '481.18']
# 4.584413109756098
# Sparse:  0.4
# ['gpu__time_duration.sum', 'usecond', '598.82']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '452.32']
# 4.309451219512194
# Sparse:  0.45
# ['gpu__time_duration.sum', 'usecond', '638.66']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '388.79']
# 3.704173018292683
# Sparse:  0.5
# ['gpu__time_duration.sum', 'usecond', '734.05']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '307.48']
# 2.9294969512195124
# Sparse:  0.525
# ['gpu__time_duration.sum', 'usecond', '731.46']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '293.16']
# 2.7930640243902443
# Sparse:  0.55
# ['gpu__time_duration.sum', 'usecond', '794.43']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '255.71']
# 2.4362614329268295
# Sparse:  0.575
# ['gpu__time_duration.sum', 'usecond', '811.71']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '236.99']
# 2.257907774390244
# Sparse:  0.6
# ['gpu__time_duration.sum', 'usecond', '824.86']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '218.92']
# 2.085746951219512
# Sparse:  0.625
# ['gpu__time_duration.sum', 'usecond', '796.16']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '212.64']
# 2.025914634146341
# Sparse:  0.65
# ['gpu__time_duration.sum', 'usecond', '833.41']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '189.59']
# 1.8063071646341462
# Sparse:  0.675
# ['gpu__time_duration.sum', 'usecond', '841.98']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '174.26']
# 1.6602515243902438
# Sparse:  0.7
# ['gpu__time_duration.sum', 'usecond', '789.25']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '171.59']
# 1.6348132621951221
# Sparse:  0.725
# ['gpu__time_duration.sum', 'usecond', '873.34']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '142.43']
# 1.3569931402439026
# Sparse:  0.75
# ['gpu__time_duration.sum', 'usecond', '844.58']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '133.89']
# 1.2756288109756095
# Sparse:  0.775
# ['gpu__time_duration.sum', 'usecond', '875.55']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '116.22']
# 1.107278963414634
# Sparse:  0.8
# ['gpu__time_duration.sum', 'usecond', '854.30']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '105.91']
# 1.0090510670731707
# Sparse:  0.825
# ['gpu__time_duration.sum', 'usecond', '886.46']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '89.10']
# 0.8488948170731706
# Sparse:  0.85
# ['gpu__time_duration.sum', 'usecond', '802.69']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '84.34']
# 0.8035442073170732
# Sparse:  0.875
# ['gpu__time_duration.sum', 'usecond', '775.07']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '72.96']
# 0.6951219512195121
# Sparse:  0.9
# ['gpu__time_duration.sum', 'usecond', '651.14']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '69.46']
# 0.6617759146341463
# Sparse:  0.925
# ['gpu__time_duration.sum', 'usecond', '536.67']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '63.22']
# 0.6023246951219512
# Sparse:  0.95
# ['gpu__time_duration.sum', 'usecond', '407.39']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '55.49']
# 0.5286775914634146
# Sparse:  0.975
# ['gpu__time_duration.sum', 'usecond', '178.98']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '63.25']
# 0.602610518292683
# Sparse:  0.98
# ['gpu__time_duration.sum', 'usecond', '152.86']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '59.27']
# 0.5646913109756099
# Sparse:  0.99
# ['gpu__time_duration.sum', 'usecond', '89.47']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '50.54']
# 0.4815167682926829
# Sparse:  0.9982
# ['gpu__time_duration.sum', 'usecond', '21.73']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '36.70']
# 0.34965701219512196
# Sparse:  0.9985
# ['gpu__time_duration.sum', 'usecond', '19.74']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '34.39']
# 0.3276486280487805
# Sparse:  0.999
# ['gpu__time_duration.sum', 'usecond', '15.62']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '29.21']
# 0.278296493902439
# Batch_size: 7680 64 2560
# Sparse:  0.3
# ['gpu__time_duration.sum', 'msecond', '1.42']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '445.03']
# 4.23999618902439
# Sparse:  0.35
# ['gpu__time_duration.sum', 'msecond', '1.77']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '331.72']
# 3.160442073170732
# Sparse:  0.4
# ['gpu__time_duration.sum', 'msecond', '1.91']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '283.50']
# 2.7010289634146343
# Sparse:  0.45
# ['gpu__time_duration.sum', 'msecond', '2.00']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '248.05']
# 2.3632812500000004
# Sparse:  0.5
# ['gpu__time_duration.sum', 'msecond', '2.09']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '216.11']
# 2.0589748475609757
# Sparse:  0.525
# ['gpu__time_duration.sum', 'msecond', '2.10']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '203.71']
# 1.9408346036585367
# Sparse:  0.55
# ['gpu__time_duration.sum', 'msecond', '2.16']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '188.87']
# 1.7994474085365852
# Sparse:  0.575
# ['gpu__time_duration.sum', 'msecond', '2.18']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '176.12']
# 1.6779725609756098
# Sparse:  0.6
# ['gpu__time_duration.sum', 'msecond', '2.23']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '161.83']
# 1.5418254573170733
# Sparse:  0.625
# ['gpu__time_duration.sum', 'msecond', '2.24']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '150.94']
# 1.4380716463414636
# Sparse:  0.65
# ['gpu__time_duration.sum', 'msecond', '2.21']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '142.64']
# 1.3589939024390243
# Sparse:  0.675
# ['gpu__time_duration.sum', 'msecond', '2.16']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '135.62']
# 1.292111280487805
# Sparse:  0.7
# ['gpu__time_duration.sum', 'msecond', '2.19']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '123.51']
# 1.176733993902439
# Sparse:  0.725
# ['gpu__time_duration.sum', 'msecond', '2.10']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '118.09']
# 1.125095274390244
# Sparse:  0.75
# ['gpu__time_duration.sum', 'msecond', '2.10']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '107.55']
# 1.0246760670731707
# Sparse:  0.775
# ['gpu__time_duration.sum', 'msecond', '2.03']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '100.04']
# 0.953125
# Sparse:  0.8
# ['gpu__time_duration.sum', 'msecond', '1.95']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '92.65']
# 0.8827172256097561
# Sparse:  0.825
# ['gpu__time_duration.sum', 'msecond', '1.89']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '83.72']
# 0.7976371951219512
# Sparse:  0.85
# ['gpu__time_duration.sum', 'msecond', '1.79']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '75.76']
# 0.7217987804878049
# Sparse:  0.875
# ['gpu__time_duration.sum', 'msecond', '1.59']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '71.16']
# 0.6779725609756098
# Sparse:  0.9
# ['gpu__time_duration.sum', 'msecond', '1.40']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '64.42']
# 0.6137576219512195
# Sparse:  0.925
# ['gpu__time_duration.sum', 'msecond', '1.12']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '60.29']
# 0.5744092987804877
# Sparse:  0.95
# ['gpu__time_duration.sum', 'usecond', '810.11']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '55.67']
# 0.5303925304878049
# Sparse:  0.975
# ['gpu__time_duration.sum', 'usecond', '388.58']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '58.21']
# 0.5545922256097561
# Sparse:  0.98
# ['gpu__time_duration.sum', 'usecond', '319.17']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '56.71']
# 0.5403010670731708
# Sparse:  0.99
# ['gpu__time_duration.sum', 'usecond', '179.78']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '50.12']
# 0.477515243902439
# Sparse:  0.9982
# ['gpu__time_duration.sum', 'usecond', '37.57']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '42.29']
# 0.40291539634146345
# Sparse:  0.9985
# ['gpu__time_duration.sum', 'usecond', '34.50']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '39.30']
# 0.37442835365853655
# Sparse:  0.999
# ['gpu__time_duration.sum', 'usecond', '24.77']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '36.48']
# 0.3475609756097561
# Batch_size: 7680 128 2560
# Sparse:  0.3
# ['gpu__time_duration.sum', 'msecond', '5.01']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '251.99']
# 2.4008193597560976
# Sparse:  0.35
# ['gpu__time_duration.sum', 'msecond', '4.75']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '246.89']
# 2.352229420731707
# Sparse:  0.4
# ['gpu__time_duration.sum', 'msecond', '5.02']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '215.91']
# 2.057069359756097
# Sparse:  0.45
# ['gpu__time_duration.sum', 'msecond', '5.17']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '192.09']
# 1.8301257621951221
# Sparse:  0.5
# ['gpu__time_duration.sum', 'msecond', '5.16']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '174.97']
# 1.667016006097561
# Sparse:  0.525
# ['gpu__time_duration.sum', 'msecond', '5.01']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '171.05']
# 1.6296684451219512
# Sparse:  0.55
# ['gpu__time_duration.sum', 'msecond', '5.16']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '157.31']
# 1.4987614329268293
# Sparse:  0.575
# ['gpu__time_duration.sum', 'msecond', '4.93']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '155.75']
# 1.4838986280487805
# Sparse:  0.6
# ['gpu__time_duration.sum', 'msecond', '5.12']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '140.99']
# 1.3432736280487805
# Sparse:  0.625
# ['gpu__time_duration.sum', 'msecond', '5.06']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '133.75']
# 1.2742949695121952
# Sparse:  0.65
# ['gpu__time_duration.sum', 'msecond', '4.99']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '126.61']
# 1.2062690548780488
# Sparse:  0.675
# ['gpu__time_duration.sum', 'msecond', '4.96']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '118.38']
# 1.1278582317073171
# Sparse:  0.7
# ['gpu__time_duration.sum', 'msecond', '4.81']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '112.71']
# 1.0738376524390243
# Sparse:  0.725
# ['gpu__time_duration.sum', 'msecond', '4.75']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '104.79']
# 0.9983803353658538
# Sparse:  0.75
# ['gpu__time_duration.sum', 'msecond', '4.60']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '98.25']
# 0.9360708841463415
# Sparse:  0.775
# ['gpu__time_duration.sum', 'msecond', '4.44']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '91.63']
# 0.8729992378048781
# Sparse:  0.8
# ['gpu__time_duration.sum', 'msecond', '4.23']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '85.58']
# 0.8153582317073171
# Sparse:  0.825
# ['gpu__time_duration.sum', 'msecond', '4.01']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '78.95']
# 0.7521913109756098
# Sparse:  0.85
# ['gpu__time_duration.sum', 'msecond', '3.67']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '73.77']
# 0.7028391768292682
# Sparse:  0.875
# ['gpu__time_duration.sum', 'msecond', '3.30']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '68.33']
# 0.6510099085365854
# Sparse:  0.9
# ['gpu__time_duration.sum', 'msecond', '2.85']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '63.20']
# 0.6021341463414634
# Sparse:  0.925
# ['gpu__time_duration.sum', 'msecond', '2.32']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '58.41']
# 0.5564977134146342
# Sparse:  0.95
# ['gpu__time_duration.sum', 'msecond', '1.67']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '54.15']
# 0.5159108231707318
# Sparse:  0.975
# ['gpu__time_duration.sum', 'usecond', '811.94']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '55.69']
# 0.5305830792682926
# Sparse:  0.98
# ['gpu__time_duration.sum', 'usecond', '665.02']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '54.30']
# 0.5173399390243902
# Sparse:  0.99
# ['gpu__time_duration.sum', 'usecond', '368.32']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '48.91']
# 0.4659870426829268
# Sparse:  0.9982
# ['gpu__time_duration.sum', 'usecond', '74.43']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '42.47']
# 0.4046303353658537
# Sparse:  0.9985
# ['gpu__time_duration.sum', 'usecond', '63.01']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '42.93']
# 0.4090129573170732
# Sparse:  0.999
# ['gpu__time_duration.sum', 'usecond', '46.24']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '39.05']
# 0.372046493902439
# Batch_size: 7680 256 2560
# Sparse:  0.3
# ['gpu__time_duration.sum', 'msecond', '11.55']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '218.84']
# 2.084984756097561
# Sparse:  0.35
# ['gpu__time_duration.sum', 'msecond', '12.00']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '195.52']
# 1.8628048780487807
# Sparse:  0.4
# ['gpu__time_duration.sum', 'msecond', '11.81']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '183.29']
# 1.7462842987804879
# Sparse:  0.45
# ['gpu__time_duration.sum', 'msecond', '10.97']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '181.03']
# 1.7247522865853657
# Sparse:  0.5
# ['gpu__time_duration.sum', 'msecond', '11.34']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '159.49']
# 1.51953125
# Sparse:  0.525
# ['gpu__time_duration.sum', 'msecond', '11.20']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '153.12']
# 1.4588414634146343
# Sparse:  0.55
# ['gpu__time_duration.sum', 'msecond', '11.11']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '146.24']
# 1.3932926829268293
# Sparse:  0.575
# ['gpu__time_duration.sum', 'msecond', '10.88']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '141.03']
# 1.3436547256097562
# Sparse:  0.6
# ['gpu__time_duration.sum', 'msecond', '10.86']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '132.98']
# 1.2669588414634145
# Sparse:  0.625
# ['gpu__time_duration.sum', 'msecond', '10.67']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '126.83']
# 1.2083650914634145
# Sparse:  0.65
# ['gpu__time_duration.sum', 'msecond', '10.54']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '119.84']
# 1.141768292682927
# Sparse:  0.675
# ['gpu__time_duration.sum', 'msecond', '9.86']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '118.99']
# 1.133669969512195
# Sparse:  0.7
# ['gpu__time_duration.sum', 'msecond', '10.10']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '107.24']
# 1.0217225609756095
# Sparse:  0.725
# ['gpu__time_duration.sum', 'msecond', '9.84']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '100.89']
# 0.9612233231707318
# Sparse:  0.75
# ['gpu__time_duration.sum', 'msecond', '9.52']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '94.73']
# 0.9025342987804879
# Sparse:  0.775
# ['gpu__time_duration.sum', 'msecond', '9.19']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '88.32']
# 0.8414634146341462
# Sparse:  0.8
# ['gpu__time_duration.sum', 'msecond', '8.72']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '82.83']
# 0.7891577743902438
# Sparse:  0.825
# ['gpu__time_duration.sum', 'msecond', '8.22']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '76.81']
# 0.7318025914634146
# Sparse:  0.85
# ['gpu__time_duration.sum', 'msecond', '7.55']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '71.66']
# 0.6827362804878049
# Sparse:  0.875
# ['gpu__time_duration.sum', 'msecond', '6.77']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '66.66']
# 0.6350990853658536
# Sparse:  0.9
# ['gpu__time_duration.sum', 'msecond', '5.81']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '62.13']
# 0.5919397865853658
# Sparse:  0.925
# ['gpu__time_duration.sum', 'msecond', '4.69']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '57.66']
# 0.5493521341463414
# Sparse:  0.95
# ['gpu__time_duration.sum', 'msecond', '3.36']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '53.73']
# 0.5119092987804877
# Sparse:  0.975
# ['gpu__time_duration.sum', 'msecond', '1.65']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '54.52']
# 0.5194359756097561
# Sparse:  0.98
# ['gpu__time_duration.sum', 'msecond', '1.36']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '53.01']
# 0.5050495426829269
# Sparse:  0.99
# ['gpu__time_duration.sum', 'usecond', '729.22']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '49.39']
# 0.4705602134146341
# Sparse:  0.9982
# ['gpu__time_duration.sum', 'usecond', '145.60']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '43.36']
# 0.413109756097561
# Sparse:  0.9985
# ['gpu__time_duration.sum', 'usecond', '125.34']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '43.13']
# 0.41091844512195125
# Sparse:  0.999
# ['gpu__time_duration.sum', 'usecond', '88.74']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '40.65']
# 0.3872903963414634
# Profile:  attention_fc 2560 2560
# Batch_size: 2560 1 2560
# Sparse:  0.3
# ['gpu__time_duration.sum', 'usecond', '52.74']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '62.43']
# 0.594798018292683
# Sparse:  0.35
# ['gpu__time_duration.sum', 'usecond', '50.34']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '60.74']
# 0.5786966463414634
# Sparse:  0.4
# ['gpu__time_duration.sum', 'usecond', '46.62']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '60.56']
# 0.5769817073170732
# Sparse:  0.45
# ['gpu__time_duration.sum', 'usecond', '43.90']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '58.94']
# 0.561547256097561
# Sparse:  0.5
# ['gpu__time_duration.sum', 'usecond', '41.02']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '57.40']
# 0.546875
# Sparse:  0.525
# ['gpu__time_duration.sum', 'usecond', '38.56']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '58.03']
# 0.5528772865853658
# Sparse:  0.55
# ['gpu__time_duration.sum', 'usecond', '37.38']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '56.68']
# 0.5400152439024389
# Sparse:  0.575
# ['gpu__time_duration.sum', 'usecond', '35.78']
# ...
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '35.48']
# 0.33803353658536583
# Sparse:  0.9985
# ['gpu__time_duration.sum', 'usecond', '26.43']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '34.34']
# 0.327172256097561
# Sparse:  0.999
# ['gpu__time_duration.sum', 'usecond', '19.74']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '30.64']
# 0.2919207317073171
# Batch_size: 2560 64 10240
# Sparse:  0.3
# ['gpu__time_duration.sum', 'msecond', '3.71']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '226.71']
# 2.159965701219512
# Sparse:  0.35
# ['gpu__time_duration.sum', 'msecond', '3.52']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '222.30']
# 2.1179496951219514
# Sparse:  0.4
# ['gpu__time_duration.sum', 'msecond', '3.87']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '186.62']
# 1.7780106707317074
# Sparse:  0.45
# ['gpu__time_duration.sum', 'msecond', '3.71']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '178.44']
# 1.7000762195121952
# Sparse:  0.5
# ['gpu__time_duration.sum', 'msecond', '3.72']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '161.53']
# 1.5389672256097562
# Sparse:  0.525
# ['gpu__time_duration.sum', 'msecond', '3.73']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '153.19']
# 1.4595083841463414
# Sparse:  0.55
# ['gpu__time_duration.sum', 'msecond', '3.67']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '147.61']
# 1.406345274390244
# Sparse:  0.575
# ['gpu__time_duration.sum', 'msecond', '3.45']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '148.27']
# 1.4126333841463417
# Sparse:  0.6
# ['gpu__time_duration.sum', 'msecond', '3.58']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '134.26']
# 1.279153963414634
# Sparse:  0.625
# ['gpu__time_duration.sum', 'msecond', '3.48']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '129.75']
# 1.236185213414634
# Sparse:  0.65
# ['gpu__time_duration.sum', 'msecond', '3.44']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '122.35']
# 1.1656821646341462
# Sparse:  0.675
# ['gpu__time_duration.sum', 'msecond', '3.34']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '117.09']
# 1.1155678353658538
# Sparse:  0.7
# ['gpu__time_duration.sum', 'msecond', '3.20']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '112.91']
# 1.0757431402439024
# Sparse:  0.725
# ['gpu__time_duration.sum', 'msecond', '3.20']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '103.28']
# 0.9839939024390244
# Sparse:  0.75
# ['gpu__time_duration.sum', 'msecond', '3.09']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '97.34']
# 0.9274009146341463
# Sparse:  0.775
# ['gpu__time_duration.sum', 'msecond', '2.99']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '90.60']
# 0.863185975609756
# Sparse:  0.8
# ['gpu__time_duration.sum', 'msecond', '2.87']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '83.93']
# 0.7996379573170733
# Sparse:  0.825
# ['gpu__time_duration.sum', 'msecond', '2.73']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '77.04']
# 0.7339939024390244
# Sparse:  0.85
# ['gpu__time_duration.sum', 'msecond', '2.56']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '70.42']
# 0.670922256097561
# Sparse:  0.875
# ['gpu__time_duration.sum', 'msecond', '2.34']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '64.19']
# 0.6115663109756097
# Sparse:  0.9
# ['gpu__time_duration.sum', 'msecond', '2.03']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '59.15']
# 0.5635480182926829
# Sparse:  0.925
# ['gpu__time_duration.sum', 'msecond', '1.65']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '54.78']
# 0.5219131097560976
# Sparse:  0.95
# ['gpu__time_duration.sum', 'msecond', '1.17']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '51.37']
# 0.48942454268292684
# Sparse:  0.975
# ['gpu__time_duration.sum', 'usecond', '628.93']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '47.83']
# 0.45569740853658536
# Sparse:  0.98
# ['gpu__time_duration.sum', 'usecond', '512.22']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '47.00']
# 0.44778963414634143
# Sparse:  0.99
# ['gpu__time_duration.sum', 'usecond', '266.82']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '45.05']
# 0.4292111280487804
# Sparse:  0.9982
# ['gpu__time_duration.sum', 'usecond', '55.87']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '37.86']
# 0.3607088414634146
# Sparse:  0.9985
# ['gpu__time_duration.sum', 'usecond', '47.94']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '37.84']
# 0.36051829268292684
# Sparse:  0.999
# ['gpu__time_duration.sum', 'usecond', '35.49']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '34.06']
# 0.3245045731707317
# Batch_size: 2560 128 10240
# Sparse:  0.3
# ['gpu__time_duration.sum', 'msecond', '8.58']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '196.31']
# 1.8703315548780488
# Sparse:  0.35
# ['gpu__time_duration.sum', 'msecond', '8.48']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '184.52']
# 1.758003048780488
# Sparse:  0.4
# ['gpu__time_duration.sum', 'msecond', '8.40']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '171.92']
# 1.6379573170731705
# Sparse:  0.45
# ['gpu__time_duration.sum', 'msecond', '8.32']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '159.05']
# 1.5153391768292683
# Sparse:  0.5
# ['gpu__time_duration.sum', 'msecond', '7.87']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '152.81']
# 1.455887957317073
# Sparse:  0.525
# ['gpu__time_duration.sum', 'msecond', '8.00']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '142.95']
# 1.3619474085365852
# Sparse:  0.55
# ['gpu__time_duration.sum', 'msecond', '7.83']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '138.28']
# 1.3174542682926829
# Sparse:  0.575
# ['gpu__time_duration.sum', 'msecond', '7.69']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '133.05']
# 1.2676257621951221
# Sparse:  0.6
# ['gpu__time_duration.sum', 'msecond', '7.56']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '127.26']
# 1.2124618902439024
# Sparse:  0.625
# ['gpu__time_duration.sum', 'msecond', '7.45']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '121.19']
# 1.1546303353658536
# Sparse:  0.65
# ['gpu__time_duration.sum', 'msecond', '7.27']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '115.80']
# 1.1032774390243902
# Sparse:  0.675
# ['gpu__time_duration.sum', 'msecond', '7.22']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '108.37']
# 1.0324885670731707
# Sparse:  0.7
# ['gpu__time_duration.sum', 'msecond', '6.87']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '105.05']
# 1.000857469512195
# Sparse:  0.725
# ['gpu__time_duration.sum', 'msecond', '6.85']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '96.63']
# 0.9206364329268293
# Sparse:  0.75
# ['gpu__time_duration.sum', 'msecond', '6.53']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '92.15']
# 0.877953506097561
# Sparse:  0.775
# ['gpu__time_duration.sum', 'msecond', '6.33']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '85.49']
# 0.8145007621951219
# Sparse:  0.8
# ['gpu__time_duration.sum', 'msecond', '6.05']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '79.52']
# 0.7576219512195121
# Sparse:  0.825
# ['gpu__time_duration.sum', 'msecond', '5.72']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '73.59']
# 0.7011242378048781
# Sparse:  0.85
# ['gpu__time_duration.sum', 'msecond', '5.25']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '68.79']
# 0.655392530487805
# Sparse:  0.875
# ['gpu__time_duration.sum', 'msecond', '4.72']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '63.73']
# 0.6071836890243901
# Sparse:  0.9
# ['gpu__time_duration.sum', 'msecond', '4.10']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '58.67']
# 0.5589748475609756
# Sparse:  0.925
# ['gpu__time_duration.sum', 'msecond', '3.29']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '54.78']
# 0.5219131097560976
# Sparse:  0.95
# ['gpu__time_duration.sum', 'msecond', '2.36']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '51.02']
# 0.48608993902439024
# Sparse:  0.975
# ['gpu__time_duration.sum', 'msecond', '1.28']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '47.12']
# 0.4489329268292683
# Sparse:  0.98
# ['gpu__time_duration.sum', 'msecond', '1.03']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '46.63']
# 0.44426448170731714
# Sparse:  0.99
# ['gpu__time_duration.sum', 'usecond', '532']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '45.17']
# 0.4303544207317074
# Sparse:  0.9982
# ['gpu__time_duration.sum', 'usecond', '106.98']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '39.50']
# 0.37633384146341464
# Sparse:  0.9985
# ['gpu__time_duration.sum', 'usecond', '92.74']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '39.06']
# 0.372141768292683
# Sparse:  0.999
# ['gpu__time_duration.sum', 'usecond', '66.85']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '36.13']
# 0.3442263719512196
# Batch_size: 2560 256 10240
# Sparse:  0.3
# ['gpu__time_duration.sum', 'msecond', '18.23']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '184.73']
# 1.7600038109756095
# Sparse:  0.35
# ['gpu__time_duration.sum', 'msecond', '17.96']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '174.20']
# 1.6596798780487803
# Sparse:  0.4
# ['gpu__time_duration.sum', 'msecond', '17.87']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '161.55']
# 1.539157774390244
# Sparse:  0.45
# ['gpu__time_duration.sum', 'msecond', '17.35']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '152.54']
# 1.4533155487804876
# Sparse:  0.5
# ['gpu__time_duration.sum', 'msecond', '16.76']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '143.53']
# 1.367473323170732
# Sparse:  0.525
# ['gpu__time_duration.sum', 'msecond', '16.54']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '138.23']
# 1.3169778963414633
# Sparse:  0.55
# ['gpu__time_duration.sum', 'msecond', '16.51']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '131.13']
# 1.2493330792682926
# Sparse:  0.575
# ['gpu__time_duration.sum', 'msecond', '16.32']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '125.27']
# 1.1935022865853657
# Sparse:  0.6
# ['gpu__time_duration.sum', 'msecond', '16.10']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '119.58']
# 1.1392911585365852
# Sparse:  0.625
# ['gpu__time_duration.sum', 'msecond', '15.62']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '115.56']
# 1.1009908536585364
# Sparse:  0.65
# ['gpu__time_duration.sum', 'msecond', '15.45']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '108.98']
# 1.0383003048780488
# Sparse:  0.675
# ['gpu__time_duration.sum', 'msecond', '15.11']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '103.54']
# 0.9864710365853658
# Sparse:  0.7
# ['gpu__time_duration.sum', 'msecond', '14.72']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '98.10']
# 0.9346417682926829
# Sparse:  0.725
# ['gpu__time_duration.sum', 'msecond', '14.21']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '93.09']
# 0.8869092987804879
# Sparse:  0.75
# ['gpu__time_duration.sum', 'msecond', '13.56']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '88.73']
# 0.8453696646341463
# Sparse:  0.775
# ['gpu__time_duration.sum', 'msecond', '12.99']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '83.33']
# 0.7939214939024389
# Sparse:  0.8
# ['gpu__time_duration.sum', 'msecond', '12.41']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '77.56']
# 0.7389481707317074
# Sparse:  0.825
# ['gpu__time_duration.sum', 'msecond', '11.59']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '72.67']
# 0.692358993902439
# Sparse:  0.85
# ['gpu__time_duration.sum', 'msecond', '10.65']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '67.77']
# 0.6456745426829268
# Sparse:  0.875
# ['gpu__time_duration.sum', 'msecond', '9.58']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '62.80']
# 0.5983231707317074
# Sparse:  0.9
# ['gpu__time_duration.sum', 'msecond', '8.24']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '58.36']
# 0.5560213414634146
# Sparse:  0.925
# ['gpu__time_duration.sum', 'msecond', '6.63']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '54.40']
# 0.5182926829268293
# Sparse:  0.95
# ['gpu__time_duration.sum', 'msecond', '4.90']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '49.12']
# 0.46798780487804875
# Sparse:  0.975
# ['gpu__time_duration.sum', 'msecond', '3.15']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '38.17']
# 0.36366234756097565
# Sparse:  0.98
# ['gpu__time_duration.sum', 'msecond', '2.60']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '36.98']
# 0.3523246951219512
# Sparse:  0.99
# ['gpu__time_duration.sum', 'msecond', '1.54']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '31.30']
# 0.29820884146341464
# Sparse:  0.9982
# ['gpu__time_duration.sum', 'usecond', '211.23']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '39.97']
# 0.38081173780487804
# Sparse:  0.9985
# ['gpu__time_duration.sum', 'usecond', '182.08']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '39.74']
# 0.37862042682926833
# Sparse:  0.999
# ['gpu__time_duration.sum', 'usecond', '130.43']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '36.97']
# 0.3522294207317073

# %%
compute_util
# Out:
# {'qkv': {1: {0.7: 0.671875,
#    0.65: 0.6737804878048781,
#    0.6: 0.666920731707317,
#    0.55: 0.6451028963414633,
#    0.5: 0.6471989329268293,
#    0.475: 0.6509146341463414,
#    0.45: 0.6403391768292682,
#    0.425: 0.6348132621951219,
#    0.4: 0.6319550304878049,
#    0.375: 0.6257621951219513,
#    0.35: 0.6221417682926829,
#    0.325: 0.6115663109756097,
#    0.3: 0.6047065548780488,
#    0.275: 0.5914634146341463,
#    0.25: 0.5836509146341463,
#    0.225: 0.5725038109756099,
#    0.2: 0.5545922256097561,
#    0.175: 0.5373475609756098,
#    0.15: 0.506859756097561,
#    0.125: 0.4876143292682927,
#    0.1: 0.43730945121951215,
#    0.075: 0.39453125,
#    0.05: 0.3113567073170732,
#    0.025: 0.27372332317073167,
#    0.02: 0.2306592987804878,
#    0.01: 0.15396341463414634,
#    0.00175: 0.040110518292682924,
#    0.0015: 0.036966463414634144,
#    0.001: 0.02458079268292683},
#   2: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0},
#   4: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0},
#   8: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0},
#   16: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0},
#   32: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0},
#   64: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0},
#   128: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0},
#   256: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0}},
#  'attention_fc': {1: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0},
#   2: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0},
#   4: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0},
#   8: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0},
#   16: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0},
#   32: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0},
#   64: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0},
#   128: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0},
#   256: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0}},
#  'linear1': {1: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0},
#   2: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0},
#   4: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0},
#   8: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0},
#   16: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0},
#   32: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0},
#   64: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0},
#   128: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0},
#   256: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0}},
#  'linear2': {1: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0},
#   2: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0},
#   4: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0},
#   8: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0},
#   16: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0},
#   32: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0},
#   64: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0},
#   128: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0},
#   256: {0.7: 0,
#    0.65: 0,
#    0.6: 0,
#    0.55: 0,
#    0.5: 0,
#    0.475: 0,
#    0.45: 0,
#    0.425: 0,
#    0.4: 0,
#    0.375: 0,
#    0.35: 0,
#    0.325: 0,
#    0.3: 0,
#    0.275: 0,
#    0.25: 0,
#    0.225: 0,
#    0.2: 0,
#    0.175: 0,
#    0.15: 0,
#    0.125: 0,
#    0.1: 0,
#    0.075: 0,
#    0.05: 0,
#    0.025: 0,
#    0.02: 0,
#    0.01: 0,
#    0.00175: 0,
#    0.0015: 0,
#    0.001: 0}}}

# %%
with open("./compute_util1.json", 'w') as file:
    json.dump(compute_util, file)

with open("./latency1.json", 'w') as file:
    json.dump(execution_time, file)

# %%
baseline = {}
baseline['compute'] = {}
baseline['time'] = {}
for layer in problem:
    baseline['compute'][layer] = {}
    baseline['time'][layer] = {}

# %%
baseline
# Out:
# {'compute': {'qkv': {}, 'attention_fc': {}, 'linear1': {}, 'linear2': {}},
#  'time': {'qkv': {}, 'attention_fc': {}, 'linear1': {}, 'linear2': {}}}

# %%
a, b = result.stdout.decode().find("smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed"),result.stdout.decode().find("gpu__time_duration.sum")

# %%
result.stdout.decode()[a:a+120].split(), result.stdout.decode()[b:b+120].split()
# Out:
# (['sm__throughput.avg.pct_of_peak_sustained_elapsed',
#   '%',
#   '22.127333',
#   '22.472679',
#   '22.319877'],
#  ['gpu__time_duration.sum', 'usecond', '34.240000', '35.552000', '34.867810'])

# %%
#cuBlas, Baseline
for layer in problem:
    m, k = problem[layer]
    print("Profile: ",layer, m, k)
    for batch in batch_size:
        print("Batch_size:", m, batch, k)
        result = subprocess.run(f"ncu --replay-mode kernel --metric smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed,smsp__cycles_elapsed.avg.per_second,gpu__time_duration.sum ./cublas_sgemm {m} {batch} {k} 0", stdout=subprocess.PIPE, shell=True)  
        idx1 = result.stdout.decode().find("gpu__time_duration.sum")
        baseline['time'][layer][batch] = float(result.stdout.decode()[idx1:idx1+120].split()[-1])
        
        idx2 = result.stdout.decode().find("smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed")
        baseline['compute'][layer][batch] = (float(result.stdout.decode()[idx2:idx2+117].split()[-1].replace(',', '')) / float(peak_flop)) * 100.0
        print(result.stdout.decode()[idx1:idx1+120].split())
        print(result.stdout.decode()[idx2:idx2+120].split())
# Out:
# Profile:  qkv 7680 2560
# Batch_size: 7680 1 2560
# ['gpu__time_duration.sum', 'usecond', '97.02']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '145.58']
# Batch_size: 7680 2 2560
# ['gpu__time_duration.sum', 'usecond', '99.87']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '282.54']
# Batch_size: 7680 4 2560
# ['gpu__time_duration.sum', 'usecond', '99.26']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '568.84']
# Batch_size: 7680 8 2560
# ['gpu__time_duration.sum', 'usecond', '115.74']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '3,906.19']
# Batch_size: 7680 16 2560
# ['gpu__time_duration.sum', 'usecond', '116.54']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '3,877.65']
# Batch_size: 7680 32 2560
# ['gpu__time_duration.sum', 'usecond', '126.85']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '3,572.74']
# Batch_size: 7680 64 2560
# ['gpu__time_duration.sum', 'usecond', '164.58']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '5,512.56']
# Batch_size: 7680 128 2560
# ['gpu__time_duration.sum', 'usecond', '312.32']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '5,800.06']
# Batch_size: 7680 256 2560
# ['gpu__time_duration.sum', 'usecond', '546.05']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '6,634.57']
# Profile:  attention_fc 2560 2560
# Batch_size: 2560 1 2560
# ['gpu__time_duration.sum', 'usecond', '35.07']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '134.38']
# Batch_size: 2560 2 2560
# ['gpu__time_duration.sum', 'usecond', '41.82']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '3,623.72']
# Batch_size: 2560 4 2560
# ['gpu__time_duration.sum', 'usecond', '41.18']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '3,688.58']
# Batch_size: 2560 8 2560
# ['gpu__time_duration.sum', 'usecond', '41.50']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '3,659.17']
# Batch_size: 2560 16 2560
# ['gpu__time_duration.sum', 'usecond', '41.60']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '3,651.26']
# Batch_size: 2560 32 2560
# ['gpu__time_duration.sum', 'usecond', '59.90']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '2,535.94']
# Batch_size: 2560 64 2560
# ['gpu__time_duration.sum', 'usecond', '65.63']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '4,624.75']
# Batch_size: 2560 128 2560
# ['gpu__time_duration.sum', 'usecond', '114.40']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '5,295.44']
# Batch_size: 2560 256 2560
# ['gpu__time_duration.sum', 'usecond', '201.66']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '6,004.84']
# Profile:  linear1 10240 2560
# Batch_size: 10240 1 2560
# ['gpu__time_duration.sum', 'usecond', '127.68']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '4,727.43']
# Batch_size: 10240 2 2560
# ['gpu__time_duration.sum', 'usecond', '131.33']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '4,610.38']
# Batch_size: 10240 4 2560
# ['gpu__time_duration.sum', 'usecond', '131.49']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '4,605.35']
# Batch_size: 10240 8 2560
# ['gpu__time_duration.sum', 'usecond', '131.39']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '4,608.38']
# Batch_size: 10240 16 2560
# ['gpu__time_duration.sum', 'usecond', '131.52']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '4,607.41']
# Batch_size: 10240 32 2560
# ['gpu__time_duration.sum', 'usecond', '136.96']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '4,414.31']
# Batch_size: 10240 64 2560
# ['gpu__time_duration.sum', 'usecond', '205.50']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '5,894.08']
# Batch_size: 10240 128 2560
# ['gpu__time_duration.sum', 'usecond', '368.03']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '6,566.16']
# Batch_size: 10240 256 2560
# ['gpu__time_duration.sum', 'usecond', '734.59']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '6,574.23']
# Profile:  linear2 2560 10240
# Batch_size: 2560 1 10240
# ['gpu__time_duration.sum', 'usecond', '137.31']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '4,397.87']
# Batch_size: 2560 2 10240
# ['gpu__time_duration.sum', 'usecond', '138.30']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '4,366.92']
# Batch_size: 2560 4 10240
# ['gpu__time_duration.sum', 'usecond', '131.94']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '4,575.56']
# Batch_size: 2560 8 10240
# ['gpu__time_duration.sum', 'usecond', '131.23']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '4,600.82']
# Batch_size: 2560 16 10240
# ['gpu__time_duration.sum', 'usecond', '141.18']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '4,283.01']
# Batch_size: 2560 32 10240
# ['gpu__time_duration.sum', 'usecond', '137.47']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '4,395.82']
# Batch_size: 2560 64 10240
# ['gpu__time_duration.sum', 'usecond', '245.82']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '4,908.37']
# Batch_size: 2560 128 10240
# ['gpu__time_duration.sum', 'usecond', '385.63']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '6,251.00']
# Batch_size: 2560 256 10240
# ['gpu__time_duration.sum', 'usecond', '751.17']
# ['smsp__sass_thread_inst_executed_op_ffma_pred_on.sum.per_cycle_elapsed', 'inst/cycle', '6,419.43']

# %%
tt = '3,910.80'.replace(',','')

# %%
float(tt)
# Out:
# 3910.8

# %%
with open("./baseline2.json", 'w') as file:
    json.dump(baseline, file)

# %%
for key in baseline['time']:
    values = baseline['time'][key]
    print(values)
# Out:
# {1: 97.383619, 2: 100.068571, 4: 99.108571, 8: 116.091429, 16: 116.592762, 32: 126.832762, 64: 164.941714, 128: 312.466286, 256: 547.608381}
# {1: 34.930286, 2: 41.426286, 4: 41.369905, 8: 41.475048, 16: 41.641143, 32: 59.943619, 64: 65.854476, 128: 114.140952, 256: 201.237333}
# {1: 127.856762, 2: 131.683048, 4: 131.707429, 8: 131.72419, 16: 131.919238, 32: 137.61981, 64: 206.134857, 128: 368.323048, 256: 735.75619}
# {1: 138.328381, 2: 138.247619, 4: 131.983238, 8: 132.120381, 16: 140.341333, 32: 136.356571, 64: 247.247238, 128: 386.706286, 256: 754.369524}
